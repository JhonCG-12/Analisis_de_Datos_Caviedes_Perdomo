# %% [markdown]
# # Ejercicios de Práctica: Visualización de Datos
# Completa los siguientes 20 ejercicios para dominar las técnicas de visualización de datos con Matplotlib y Seaborn.

# %% [markdown]
# ### 1. Importar Librerías
# Importa las librerías necesarias: `numpy`, `pandas`, `matplotlib.pyplot` (como `plt`) y `seaborn` (como `sns`). ⚛

# %%
# Tu código aquí
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Crear el Dataset
# Ejecuta la siguiente celda para crear los DataFrames que usaremos en los ejercicios.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de estilo
sns.set_theme(style='whitegrid')
np.random.seed(42)

# Dataset 1: Ventas mensuales
meses = ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic']
ventas_2022 = [45, 52, 48, 65, 70, 85, 90, 88, 75, 80, 95, 110]
ventas_2023 = [50, 58, 55, 72, 78, 92, 98, 95, 82, 88, 105, 120]

df_ventas = pd.DataFrame({
    'Mes': meses,
    'Ventas_2022': ventas_2022,
    'Ventas_2023': ventas_2023
})

# Dataset 2: Datos de empleados
n_empleados = 150
df_empleados = pd.DataFrame({
    'Edad': np.random.normal(35, 8, n_empleados).astype(int).clip(22, 65),
    'Salario': np.random.normal(50000, 15000, n_empleados).clip(25000, 120000),
    'Años_Experiencia': np.random.normal(8, 4, n_empleados).clip(0, 30),
    'Departamento': np.random.choice(['Ventas', 'IT', 'Marketing', 'RRHH'], n_empleados),
    'Satisfaccion': np.random.randint(1, 11, n_empleados)
})

# Dataset 3: Productos
productos = ['Laptop', 'Mouse', 'Teclado', 'Monitor', 'Auriculares']
unidades_vendidas = [120, 450, 380, 210, 290]

df_productos = pd.DataFrame({
    'Producto': productos,
    'Unidades': unidades_vendidas
})

print('Datasets creados exitosamente')
print(f'\ndf_ventas: {df_ventas.shape}')
print(f'df_empleados: {df_empleados.shape}')
print(f'df_productos: {df_productos.shape}')
# Out:
# Datasets creados exitosamente
#
# df_ventas: (12, 3)
# df_empleados: (150, 5)
# df_productos: (5, 2)

# %% [markdown]
# ### 3. Gráfico de Líneas Simple
# Crea un gráfico de líneas que muestre las ventas de 2022 (`Ventas_2022`) a lo largo de los meses. Usa `plt.plot()` y añade título y etiquetas a los ejes.

# %%
# Tu código aquí
plt.figure(figsize=(10,5))
plt.plot(df_ventas['Mes'], df_ventas['Ventas_2022'])
plt.title('Ventas 2022 por Mes')
plt.xlabel('Mes')
plt.ylabel('Ventas')
plt.xticks(rotation=45)
plt.savefig('Grafico3.png', dpi=300)
plt.show()

# %% [markdown]
# De acuerdo a la gráfica anterior de ventas 2022 por meses, se evidencia lo siguiente:
# - El promedio de ventas del 2022 fue de 77.5.
# - Los meses de mayor auge son (julio, octubre, noviembre y diciembre) con un promedio de 92.5.
# - Los meses de menores ventas fueron: Enero, febrero y marzo esto posiblemente debido a comienzo del año y temas escolares y postvacaciones.

# %%
df_ventas[ 'Ventas_2022'].describe().T
# Out:
# count     12.00000
# mean      75.25000
# std       20.05957
# min       45.00000
# 25%       61.75000
# 50%       77.50000
# 75%       88.50000
# max      110.00000
# Name: Ventas_2022, dtype: float64

# %% [markdown]
# ### 4. Gráfico de Líneas Múltiples
# Crea un gráfico que muestre las ventas de 2022 y 2023 en la misma figura. Usa diferentes colores y añade una leyenda.

# %%
# Tu código aquí
plt.figure(figsize=(10,5))
plt.plot(df_ventas['Mes'], df_ventas['Ventas_2022'], color='#9c27b0', label='2022')
plt.plot(df_ventas['Mes'], df_ventas['Ventas_2023'], color='#c62828', label='2023')
plt.title('Ventas 2022 vs 2023')
plt.xlabel('Mes')
plt.ylabel('Ventas')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
df_ventas[['Ventas_2022', 'Ventas_2023']].describe().T
# Out:
#              count   mean        std   min    25%   50%    75%    max
# Ventas_2022   12.0  75.25  20.059570  45.0  61.75  77.5  88.50  110.0
# Ventas_2023   12.0  82.75  21.260826  50.0  68.50  85.0  95.75  120.0

# %% [markdown]
# De acuerdo a la gráfica anterior evidenciamos lo siguiente:
# - Las ventas del años 2023 siguen la tendencia del año 2022, con un aumento de 7.5 unidades de ventas.
# - El aumento de ventas ha generado un aumento en la dispersión de los datos, con una poca posibilidad de predicción de ventas.

# %% [markdown]
# ### 5. Gráfico de Barras Vertical
# Crea un gráfico de barras vertical que muestre las unidades vendidas por producto usando `df_productos`. Añade título y etiquetas.

# %%
# Tu código aquí
plt.figure(figsize=(8,5))
plt.bar(df_productos['Producto'], df_productos['Unidades'])
plt.title('Unidades Vendidas por Producto')
plt.xlabel('Producto')
plt.ylabel('Unidades')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# De acuerdo con la grafica anterior:
# - Los periféricos presentar mayor venta que los dispositivos principales
# - En julio, octubre, noviembre y diciembre estos periféricos se venden con mayor frecuencia
# - Se sugiere a gerencia, esstablecer dos estrategias:
# 1. Incrementar la fuerza de venta en los meses de baja rotación
# 2. Mantener la tendencia en los 4 meses de mayor venta

# %% [markdown]
# ### 6. Gráfico de Barras Horizontal
# Crea el mismo gráfico anterior pero con barras horizontales usando `plt.barh()`.

# %%
# Tu código aquí
plt.figure(figsize=(8,5))
plt.barh(df_productos['Producto'], df_productos['Unidades'])
plt.title('Unidades Vendidas por Producto (Horizontal)')
plt.xlabel('Unidades')
plt.ylabel('Producto')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 7. Histograma
# Crea un histograma de la distribución de edades de los empleados (`df_empleados['Edad']`). Usa 15 bins y añade título.

# %%
# Tu código aquí
plt.figure(figsize=(10,6))
plt.hist(df_empleados['Edad'], bins=20)
plt.title('Distribución de Edades')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45)
plt.show()

# %%
df_empleados[ 'Edad']. describe().T
# Out:
# count    150.000000
# mean      34.000000
# std        7.233405
# min       22.000000
# 25%       29.000000
# 50%       34.000000
# 75%       38.000000
# max       54.000000
# Name: Edad, dtype: float64

# %% [markdown]
# De acuerdo con la gráfica anterior se evidencia lo siguiente:
#
# - La variable de edad es normal, debido a que su media es igual a la mediana, esto posibilita una mejor predicción.
#
# - El promedio de edad de los empleados es de 34 años
#
# - La desviación estandar es pequeña lo cual confirma su suficiencia estadistica para predecir correctamente

# %% [markdown]
# ### 8. Gráfico de Dispersión (Scatter Plot)
# Crea un gráfico de dispersión que muestre la relación entre `Años_Experiencia` (eje X) y `Salario` (eje Y) de `df_empleados`.

# %%
# Tu código aquí
plt.figure(figsize=(10,6))
plt.scatter(df_empleados['Años_Experiencia'], df_empleados['Salario'])
plt.title('Experiencia vs Salario')
plt.xlabel('Años de Experiencia')
plt.ylabel('Salario')
plt.show()

# %% [markdown]
# De acuerdo con la gráfica anterior:
# - Se evidencia ausencia de plan carrera, o falta de interes en promoción  ya que conservan durante los años  los mismos salarios.
# - Se evidencia a partir del años 12.5 en adelante un retiro de las personas y/0 empleados de la empresa.
# - El aumento de salario es inferior a 80000 USD, solo 6 personas

# %% [markdown]
# ### 9. Gráfico de Pastel (Pie Chart)
# Crea un gráfico de pastel que muestre la proporción de unidades vendidas por producto. Usa `plt.pie()` y muestra los porcentajes.

# %%
# Tu código aquí
plt.figure(figsize=(10,6))
plt.pie(df_productos['Unidades'], labels=df_productos['Producto'], autopct='%1.1f%%', explode=[0, 0.1,0.1,0,0], startangle=240)
plt.title('Proporción de Unidades Vendidas por Producto')
plt.show()

# %% [markdown]
# Se evidencia en la gráfica de torta  que las ventas estan distribuidas en un 77% entre auriculares, mouse y teclado

# %% [markdown]
# ### 10. Box Plot (Diagrama de Caja)
# Crea un box plot de los salarios por departamento usando `df_empleados`. Usa `sns.boxplot()`.

# %%
# Tu código aquí
plt.figure(figsize=(10,6))
sns.boxplot(data=df_empleados, x='Departamento', y='Salario')
plt.title('Salario por Departamento')
plt.xlabel('Departamento')
plt.ylabel('Salario')
plt.show()

# %% [markdown]
# Según el diagrama de caja se evidencia un valor medio de salario para todas las áreas similar, no hay promoción y desde el punto de vista técnico hay ruido en la clasificación de IT.

# %% [markdown]
# ### 11. Violin Plot
# Crea un violin plot de los salarios por departamento. Usa `sns.violinplot()` y compara con el box plot anterior.

# %%
# Tu código aquí
plt.figure(figsize=(10,6))
sns.violinplot(data=df_empleados, x='Departamento', y='Salario')
plt.title('Distribución de Salarios por Departamento')
plt.xlabel('Departamento')
plt.ylabel('Salario')
plt.show()

# %%
df_empleados[[ 'Departamento', 'Salario']].describe().T
# Out:
#          count         mean           std      min           25%  \
# Salario  150.0  51310.35586  14764.793499  25000.0  39654.674347
#
#                   50%           75%           max
# Salario  52133.492624  60128.464705  107790.97236

# %% [markdown]
# ### 12. Histograma con Seaborn (Histplot)
# Crea un histograma de la distribución de salarios usando `sns.histplot()`. Añade una curva KDE (Kernel Density Estimate).

# %%
# Tu código aquí
plt.figure(figsize=(10,5))
sns.histplot(df_empleados['Salario'], kde=True)
plt.title('Distribución de Salarios con KDE')
plt.xlabel('Salario')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# Según la grafica El pico principal del KDE está entre: 50,000 y 60,000
#
# En el extremo derecho del histograma se observan barras con muy poca frecuencia, lo cual sugiere:
#
# -  Empleados con salarios significativamente mayores al promedio.
# -  Estos valores no son comunes en la población.
#
# Se observa una variación grande:
#
# - Desde salarios alrededor de 25,000 – 30,000
#
# - Hasta valores que superan los 100,000

# %% [markdown]
# ### 13. Count Plot
# Crea un gráfico de conteo que muestre cuántos empleados hay en cada departamento. Usa `sns.countplot()`.

# %%
# Tu código aquí
plt.figure(figsize=(10,5))
sns.countplot(data=df_empleados, x='Departamento')
plt.title('Cantidad de Empleados por Departamento')
plt.xlabel('Salario')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# Con base a la gráfica  concluimos lo siguiente:
# - IT es el departamento con mayor cantidad de empleados, aproximadamente 44.
#
# - IT es probablemente un área estratégica en la organización, dado que concentra el mayor número de empleados.
#
# - RRHH siendo el más pequeño, es coherente con muchas estructuras organizacionales, ya que suele requerir menos personal al encargarse de funciones administrativas y de apoyo.

# %% [markdown]
# ### 14. Scatter Plot con Seaborn
# Crea un scatter plot de `Edad` vs `Salario` usando `sns.scatterplot()`. Colorea los puntos según el `Departamento`.

# %%
# Tu código aquí
plt.figure(figsize=(10,5))
sns.scatterplot(data=df_empleados, x='Edad', y='Salario', hue='Departamento')
plt.title('Edad vs Salario por Departamento')
plt.xlabel('Edad')
plt.ylabel('Salario')
plt.show()

# %% [markdown]
# En la gráfica se observa lo siguiente:
#
# - Personas entre 25 y 40 años tienen una gran dispersión salarial (aprox. 30,000–80,000 e incluso más).
#
# - La variación salarial depende más del departamento y nivel de especialización que de la edad.
#
# - IT y Ventas presentan los rangos salariales más amplios y altos.

# %% [markdown]
# ### 15. Heatmap de Correlación
# Crea un heatmap que muestre la matriz de correlación de las variables numéricas de `df_empleados`. Usa `sns.heatmap()` con `annot=True`.

# %%
# Tu código aquí
plt.figure(figsize=(10,5))
correlacion_matrix = df_empleados[['Edad', 'Salario','Años_Experiencia','Satisfaccion']].corr(method='spearman')
sns.heatmap(correlacion_matrix, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# Según la grafica se evidencia lo siguiente:
#
# - Las variables se comportan casi de manera independiente entre sí.
#
# - La edad no determina ni el salario ni la experiencia ni la satisfacción.
#
# - La satisfacción laboral no depende de los demás factores medidos.
#
# - Esto sugiere una dinámica laboral diversa donde no existe una regla clara que relacione estos factores.

# %%
correlacion_matrix
# Out:
#                       Edad   Salario  Años_Experiencia  Satisfaccion
# Edad              1.000000 -0.031873         -0.029123      0.084097
# Salario          -0.031873  1.000000          0.002814     -0.024712
# Años_Experiencia -0.029123  0.002814          1.000000     -0.051213
# Satisfaccion      0.084097 -0.024712         -0.051213      1.000000

# %% [markdown]
# ### 16. Pair Plot
# Crea un pair plot de las variables numéricas de `df_empleados` coloreado por `Departamento`. Usa `sns.pairplot()`.

# %%
# Tu código aquí
sns.pairplot(df_empleados, hue='Departamento', vars=['Edad', 'Salario', 'Años_Experiencia', 'Satisfaccion'])
plt.suptitle('Pair Plot de Variables Numéricas Coloreado por Departamento', y=1.02)
plt.show()

# %% [markdown]
# En la gráfica se observa:
# - IT tiene una ligera presencia de edades un poco mayores.
#
# - Marketing y RRHH se concentran en salarios medios.
#
# - La mayoría de empleados tiene entre 3 y 12 años de experiencia.
#
# - RRHH muestra cierta variabilidad en satisfacción.

# %% [markdown]
# ### 17. Subplots (Múltiples Gráficos)
# Crea una figura con 2 subplots (1 fila, 2 columnas):
# - Subplot 1: Histograma de edades
# - Subplot 2: Histograma de salarios
#
# Usa `plt.subplots()`.

# %%
# Tu código aquí
fig, axes = plt.subplots(2, 2, figsize=(12, 8))


axes[0, 0].hist(df_empleados['Edad'], bins=15)
axes[0, 0].set_title('Distribución de Edades')
axes[0, 0].set_xlabel('Edad')
axes[0, 0].set_ylabel('Frecuencia')

axes[0, 1].hist(df_empleados['Salario'], bins=15, color='orange')
axes[0, 1].set_title('Distribución de Salarios')
axes[0, 1].set_xlabel('Salario')
axes[0, 1].set_ylabel('Frecuencia')

axes[1, 0].hist(df_empleados['Edad'], bins=15)
axes[1, 0].set_title('Distribución de Edades')
axes[1, 0].set_xlabel('Edad')
axes[1, 0].set_ylabel('Frecuencia')


axes[1, 1].hist(df_empleados['Salario'], bins=15, color='orange')
axes[1, 1].set_title('Distribución de Salarios')
axes[1, 1].set_xlabel('Salario')
axes[1, 1].set_ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# Se observa una distribución ligeramente sesgada hacia la derecha, indicando que hay menos empleados en edades mayores. Las edades extremas (menores de 23 y mayores de 50) son poco frecuentes.
#
# Esto sugiere una estructura salarial típica:
# Una mayoría con salarios medios y una minoría con salarios altos, posiblemente por cargos ejecutivos o técnicos (como ocurrió en análisis previos con el departamento de IT)

# %% [markdown]
# ### 18. Gráfico de Barras Agrupadas
# Crea un gráfico de barras agrupadas que compare las ventas de 2022 y 2023 por mes. Usa `df_ventas` y el método `.plot(kind='bar')`.

# %%
# Tu código aquí
df_ventas.plot(x='Mes', y=['Ventas_2022', 'Ventas_2023'], kind='bar', figsize=(12, 6))
plt.title('Comparación de Ventas 2022 vs 2023')
plt.ylabel('Ventas')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# En la gráfica con base a los datos se observa lo siguiente:
#
# -  Indica un crecimiento sostenido mes a mes respecto al año anterior
#
# - Este trimestre sugiere un fuerte cierre del año, posiblemente por campañas, estacionalidad o mayor demanda.
#
# - La empresa experimentó un crecimiento sostenido durante 2023 en relación con 2022, demostrando una tendencia positiva en su rendimiento anual.

# %% [markdown]
# ### 19. Personalización Avanzada
# Crea un scatter plot de `Años_Experiencia` vs `Salario` con las siguientes personalizaciones:
# - Tamaño de figura: 10x6
# - Color de puntos: verde
# - Transparencia (alpha): 0.6
# - Tamaño de puntos: 50
# - Grid activado
# - Título con tamaño de fuente 16
# - Etiquetas de ejes con tamaño de fuente 12

# %%
# Tu código aquí
plt.figure(figsize=(10, 6))
plt.scatter(df_empleados['Años_Experiencia'], df_empleados['Salario'], color='green', alpha=0.6, s=50)
plt.grid(True)
plt.title('Años de Experiencia vs Salario (Personalizado)', fontsize=16)
plt.xlabel('Años de Experiencia', fontsize=12)
plt.ylabel('Salario', fontsize=12)
plt.show()

# %% [markdown]
# Como se observa en la gráfica:
#
# - La relación entre ambas variables es prácticamente nula y coincide con lo visto en el heatmap de correlación.
#
# - La dispersión es amplia, lo que refleja diferentes rutas profesionales, cargos o niveles de compensación.
#
# Esto indica que las políticas salariales no están estrictamente relacionadas con la antigüedad, sino con otros factores adicionales.

# %% [markdown]
# ### 20. Guardar una Figura
# Crea cualquier gráfico de tu elección y guárdalo como un archivo PNG con el nombre `mi_grafico.png` usando `plt.savefig()`. Asegúrate de usar `dpi=300` para alta calidad.

# %%
# Tu código aquí
plt.figure(figsize=(8,5))
plt.plot(df_ventas['Mes'], df_ventas['Ventas_2022'])
plt.title('Gráfico Guardado')
plt.savefig('mi_grafico.png', dpi=300)
plt.show()

# %% [markdown]
# Como podemos observar en la gráfica evidenciamos lo siguiente:
# - El cierre del año es muy fuerte, posiblemente por temporadas altas o estrategias comerciales exitosas.
#
# - El gráfico muestra subidas y bajadas, pero el patrón general es de crecimiento sostenido, lo cual es positivo para la empresa.
#
# - Una tendencia general que apunta a un crecimiento en ventas, útil para proyecciones futuras.

# %% [markdown]
# ## ¡Felicidades! ✔
# Has completado los 20 ejercicios de visualización de datos. Ahora tienes las habilidades necesarias para crear visualizaciones efectivas y comunicar insights de tus datos de manera clara y profesional. Recuerda por cada celda debes explicar lo evidenciado en la gráfica.
